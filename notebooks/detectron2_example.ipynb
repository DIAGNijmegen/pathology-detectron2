# %%
# %config IPCompleter.use_jedi = False

# %%
import wholeslidedata
from wholeslidedata.iterators import create_batch_iterator
import os

# %%
import detectron2
import torch
from detectron2.structures import (
    BoxMode,
    Instances,
    Boxes
)
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2 import model_zoo

# %%
from wholeslidedata.iterators import BatchIterator
import numpy as np
class Detectron22DataLoader(BatchIterator):
    def __next__(self):
        x_batch, y_batch = super().__next__()
        x_batch = x_batch / 255.0
        
        batch_dicts = []
        for idx, x_sample in enumerate(x_batch):
            sample_dict = {}
#             print(y_batch[idx])
            target_gt_boxes = self._get_gt_boxes(y_batch[idx], x_sample.shape[:2])
            image = image.transpose(2, 0, 1).astype("float32")
            sample_dict['instances'] = target_gt_boxes
            sample_dict['image'] = torch.as_tensor(image)
            batch_dicts.append(sample_dict)
        return batch_dicts

    def _get_gt_boxes(self, y_sample, image_size):
        y_boxes = y_sample[~np.all(y_sample == 0, axis=-1)]
        boxes = [BoxMode.convert(obj[:4], BoxMode.XYXY_ABS, BoxMode.XYXY_ABS) for obj in y_boxes]
        target = Instances(image_size)
        target.gt_boxes = Boxes(boxes)
        classes = [int(obj[-2]) for obj in y_boxes]
        classes = torch.tensor(classes, dtype=torch.int64)
        target.gt_classes = classes
        return target

# %%
class WholeSlideDataDetectionTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        user_config = './configs/detection_config.yml'
        cpus = 1
        mode = 'training'

        training_batch_generator =  create_batch_iterator(user_config=user_config, 
                                    mode=mode, 
                                    cpus=cpus, 
                                    iterator_class=Detectron22DataLoader) 
        return training_batch_generator

# %%
user_config = './configs/detection_config.yml'
cpus = 1
mode = 'training'

training_batch_generator =  create_batch_iterator(user_config=user_config, 
                            mode=mode, 
                            cpus=cpus, 
                            iterator_class=Detectron22DataLoader)

# %%
def train():
#     coco_datadict = get_pannuke_coco_datadict(data_folder, fold)
#     register(fold, coco_datadict)
    cfg = get_cfg()
    cfg.merge_from_file(
        model_zoo.get_config_file("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml")
    )
    cfg.DATASETS.TRAIN = ("detection_dataset2",)
    cfg.DATASETS.TEST = ()
    cfg.DATALOADER.NUM_WORKERS = 1
#     cfg.MODEL.WEIGHTS = "detectron2://COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x/139173657/model_final_68b088.pkl"  # Let training initialize from model zoo
    # cfg.MODEL.WEIGHTS = None
    cfg.SOLVER.IMS_PER_BATCH = 8
    cfg.SOLVER.BASE_LR = 0.00001  # pick a good LR
    cfg.SOLVER.MAX_ITER = 200000  # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
    cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = (
        64  # faster, and good enough for this toy dataset (default: 512)
    )
    cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1
    cfg.OUTPUT_DIR = '/home/user/output/'
    cfg.SOLVER.STEPS = (1000, 10000, 20000, 50000, 100000)
    cfg.SOLVER.WARMUP_ITERS = 100
    cfg.SOLVER.GAMMA = 0.5
    os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
    trainer = WholeSlideDataDetectionTrainer(cfg)
    trainer.resume_or_load(resume=False)
    trainer.train()

# %%
train()
# Out:
# [09/21 19:42:26 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# [09/21 19:42:26 d2.checkpoint.c2_model_loading]: Renaming Caffe2 weights ......
# [09/21 19:42:27 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up:
# | Names in Model    | Names in Checkpoint                         | Shapes                                          |
# |:------------------|:--------------------------------------------|:------------------------------------------------|
# | res2.0.conv1.*    | res2_0_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | res2.0.conv2.*    | res2_0_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,8,3,3)         |
# | res2.0.conv3.*    | res2_0_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res2.0.shortcut.* | res2_0_branch1_{bn_b,bn_rm,bn_riv,bn_s,w}   | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | res2.1.conv1.*    | res2_1_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res2.1.conv2.*    | res2_1_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,8,3,3)         |
# | res2.1.conv3.*    | res2_1_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res2.2.conv1.*    | res2_2_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res2.2.conv2.*    | res2_2_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,8,3,3)         |
# | res2.2.conv3.*    | res2_2_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res3.0.conv1.*    | res3_0_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,256,1,1)       |
# | res3.0.conv2.*    | res3_0_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,16,3,3)        |
# | res3.0.conv3.*    | res3_0_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.0.shortcut.* | res3_0_branch1_{bn_b,bn_rm,bn_riv,bn_s,w}   | (512,) (512,) (512,) (512,) (512,256,1,1)       |
# | res3.1.conv1.*    | res3_1_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.1.conv2.*    | res3_1_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,16,3,3)        |
# | res3.1.conv3.*    | res3_1_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.2.conv1.*    | res3_2_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.2.conv2.*    | res3_2_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,16,3,3)        |
# | res3.2.conv3.*    | res3_2_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.3.conv1.*    | res3_3_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.3.conv2.*    | res3_3_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,16,3,3)        |
# | res3.3.conv3.*    | res3_3_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res4.0.conv1.*    | res4_0_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,512,1,1)  |
# | res4.0.conv2.*    | res4_0_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.0.conv3.*    | res4_0_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.0.shortcut.* | res4_0_branch1_{bn_b,bn_rm,bn_riv,bn_s,w}   | (1024,) (1024,) (1024,) (1024,) (1024,512,1,1)  |
# | res4.1.conv1.*    | res4_1_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.1.conv2.*    | res4_1_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.1.conv3.*    | res4_1_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.10.conv1.*   | res4_10_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.10.conv2.*   | res4_10_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.10.conv3.*   | res4_10_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.11.conv1.*   | res4_11_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.11.conv2.*   | res4_11_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.11.conv3.*   | res4_11_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.12.conv1.*   | res4_12_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.12.conv2.*   | res4_12_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.12.conv3.*   | res4_12_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.13.conv1.*   | res4_13_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.13.conv2.*   | res4_13_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.13.conv3.*   | res4_13_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.14.conv1.*   | res4_14_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.14.conv2.*   | res4_14_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.14.conv3.*   | res4_14_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.15.conv1.*   | res4_15_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.15.conv2.*   | res4_15_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.15.conv3.*   | res4_15_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.16.conv1.*   | res4_16_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.16.conv2.*   | res4_16_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.16.conv3.*   | res4_16_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.17.conv1.*   | res4_17_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.17.conv2.*   | res4_17_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.17.conv3.*   | res4_17_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.18.conv1.*   | res4_18_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.18.conv2.*   | res4_18_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.18.conv3.*   | res4_18_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.19.conv1.*   | res4_19_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.19.conv2.*   | res4_19_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.19.conv3.*   | res4_19_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.2.conv1.*    | res4_2_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.2.conv2.*    | res4_2_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.2.conv3.*    | res4_2_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.20.conv1.*   | res4_20_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.20.conv2.*   | res4_20_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.20.conv3.*   | res4_20_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.21.conv1.*   | res4_21_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.21.conv2.*   | res4_21_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.21.conv3.*   | res4_21_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.22.conv1.*   | res4_22_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.22.conv2.*   | res4_22_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.22.conv3.*   | res4_22_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.3.conv1.*    | res4_3_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.3.conv2.*    | res4_3_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.3.conv3.*    | res4_3_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.4.conv1.*    | res4_4_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.4.conv2.*    | res4_4_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.4.conv3.*    | res4_4_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.5.conv1.*    | res4_5_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.5.conv2.*    | res4_5_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.5.conv3.*    | res4_5_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.6.conv1.*    | res4_6_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.6.conv2.*    | res4_6_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.6.conv3.*    | res4_6_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.7.conv1.*    | res4_7_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.7.conv2.*    | res4_7_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.7.conv3.*    | res4_7_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.8.conv1.*    | res4_8_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.8.conv2.*    | res4_8_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.8.conv3.*    | res4_8_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.9.conv1.*    | res4_9_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.9.conv2.*    | res4_9_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.9.conv3.*    | res4_9_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res5.0.conv1.*    | res5_0_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,1024,1,1) |
# | res5.0.conv2.*    | res5_0_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,64,3,3)   |
# | res5.0.conv3.*    | res5_0_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | res5.0.shortcut.* | res5_0_branch1_{bn_b,bn_rm,bn_riv,bn_s,w}   | (2048,) (2048,) (2048,) (2048,) (2048,1024,1,1) |
# | res5.1.conv1.*    | res5_1_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | res5.1.conv2.*    | res5_1_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,64,3,3)   |
# | res5.1.conv3.*    | res5_1_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | res5.2.conv1.*    | res5_2_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | res5.2.conv2.*    | res5_2_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,64,3,3)   |
# | res5.2.conv3.*    | res5_2_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | stem.conv1.norm.* | res_conv1_bn_{b,rm,riv,s}                   | (64,) (64,) (64,) (64,)                         |
# | stem.conv1.weight | conv1_w                                     | (64, 3, 7, 7)                                   |
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   linear.{bias, weight}
# [09/21 19:42:27 d2.engine.train_loop]: Starting training from iteration 0
# [09/21 19:42:33 d2.utils.events]:  eta: 16:24:32  iter: 19  total_loss: 1.761  loss_cls: 0.5831  loss_box_reg: 0  loss_rpn_cls: 0.694  loss_rpn_loc: 0.4809  time: 0.2927  data_time: 0.0132  lr: 1.9081e-06  max_mem: 2825M
# [09/21 19:42:39 d2.utils.events]:  eta: 16:32:08  iter: 39  total_loss: 1.524  loss_cls: 0.3682  loss_box_reg: 0  loss_rpn_cls: 0.6924  loss_rpn_loc: 0.4507  time: 0.2967  data_time: 0.0028  lr: 3.9061e-06  max_mem: 2825M
# [09/21 19:42:45 d2.utils.events]:  eta: 16:32:42  iter: 59  total_loss: 1.287  loss_cls: 0.1605  loss_box_reg: 0  loss_rpn_cls: 0.6908  loss_rpn_loc: 0.4608  time: 0.2968  data_time: 0.0021  lr: 5.9041e-06  max_mem: 2825M
# [09/21 19:42:51 d2.utils.events]:  eta: 16:32:36  iter: 79  total_loss: 1.174  loss_cls: 0.0749  loss_box_reg: 0  loss_rpn_cls: 0.6864  loss_rpn_loc: 0.4164  time: 0.2978  data_time: 0.0033  lr: 7.9021e-06  max_mem: 2825M
# [09/21 19:42:57 d2.utils.events]:  eta: 16:31:50  iter: 99  total_loss: 1.121  loss_cls: 0.04373  loss_box_reg: 0  loss_rpn_cls: 0.6814  loss_rpn_loc: 0.387  time: 0.2972  data_time: 0.0022  lr: 9.9001e-06  max_mem: 2825M
# [09/21 19:43:03 d2.utils.events]:  eta: 16:32:13  iter: 119  total_loss: 1.092  loss_cls: 0.02733  loss_box_reg: 0  loss_rpn_cls: 0.6758  loss_rpn_loc: 0.3892  time: 0.2973  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:09 d2.utils.events]:  eta: 16:34:40  iter: 139  total_loss: 1.108  loss_cls: 0.02128  loss_box_reg: 0  loss_rpn_cls: 0.67  loss_rpn_loc: 0.4163  time: 0.2978  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:15 d2.utils.events]:  eta: 16:32:12  iter: 159  total_loss: 1.04  loss_cls: 0.01633  loss_box_reg: 0  loss_rpn_cls: 0.6635  loss_rpn_loc: 0.3608  time: 0.2977  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:21 d2.utils.events]:  eta: 16:33:24  iter: 179  total_loss: 1.063  loss_cls: 0.01398  loss_box_reg: 0  loss_rpn_cls: 0.6578  loss_rpn_loc: 0.3892  time: 0.2979  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:27 d2.utils.events]:  eta: 16:34:35  iter: 199  total_loss: 1.027  loss_cls: 0.01145  loss_box_reg: 0  loss_rpn_cls: 0.652  loss_rpn_loc: 0.3633  time: 0.2980  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:33 d2.utils.events]:  eta: 16:35:06  iter: 219  total_loss: 1.077  loss_cls: 0.009719  loss_box_reg: 0  loss_rpn_cls: 0.6538  loss_rpn_loc: 0.4145  time: 0.2982  data_time: 0.0024  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:39 d2.utils.events]:  eta: 16:34:35  iter: 239  total_loss: 0.9342  loss_cls: 0.008484  loss_box_reg: 0  loss_rpn_cls: 0.6338  loss_rpn_loc: 0.2912  time: 0.2982  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:45 d2.utils.events]:  eta: 16:35:10  iter: 259  total_loss: 1.005  loss_cls: 0.007612  loss_box_reg: 0  loss_rpn_cls: 0.6395  loss_rpn_loc: 0.3584  time: 0.2983  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:51 d2.utils.events]:  eta: 16:34:53  iter: 279  total_loss: 0.975  loss_cls: 0.006417  loss_box_reg: 0  loss_rpn_cls: 0.6332  loss_rpn_loc: 0.3351  time: 0.2983  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:43:57 d2.utils.events]:  eta: 16:35:27  iter: 299  total_loss: 0.9421  loss_cls: 0.006363  loss_box_reg: 0  loss_rpn_cls: 0.6288  loss_rpn_loc: 0.3052  time: 0.2985  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:03 d2.utils.events]:  eta: 16:35:30  iter: 319  total_loss: 0.8708  loss_cls: 0.004787  loss_box_reg: 0  loss_rpn_cls: 0.6149  loss_rpn_loc: 0.2525  time: 0.2987  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:09 d2.utils.events]:  eta: 16:35:24  iter: 339  total_loss: 0.9114  loss_cls: 0.005244  loss_box_reg: 0  loss_rpn_cls: 0.6219  loss_rpn_loc: 0.2838  time: 0.2985  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:15 d2.utils.events]:  eta: 16:34:29  iter: 359  total_loss: 0.8002  loss_cls: 0.00384  loss_box_reg: 0  loss_rpn_cls: 0.5998  loss_rpn_loc: 0.1966  time: 0.2978  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:21 d2.utils.events]:  eta: 16:34:34  iter: 379  total_loss: 0.8076  loss_cls: 0.003962  loss_box_reg: 0  loss_rpn_cls: 0.5952  loss_rpn_loc: 0.2026  time: 0.2978  data_time: 0.0038  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:27 d2.utils.events]:  eta: 16:34:36  iter: 399  total_loss: 0.7694  loss_cls: 0.003434  loss_box_reg: 0  loss_rpn_cls: 0.5879  loss_rpn_loc: 0.178  time: 0.2977  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:33 d2.utils.events]:  eta: 16:34:22  iter: 419  total_loss: 0.7241  loss_cls: 0.002782  loss_box_reg: 0  loss_rpn_cls: 0.5781  loss_rpn_loc: 0.1419  time: 0.2978  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:39 d2.utils.events]:  eta: 16:34:04  iter: 439  total_loss: 0.724  loss_cls: 0.002655  loss_box_reg: 0  loss_rpn_cls: 0.5853  loss_rpn_loc: 0.136  time: 0.2978  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:45 d2.utils.events]:  eta: 16:33:17  iter: 459  total_loss: 0.6681  loss_cls: 0.002197  loss_box_reg: 0  loss_rpn_cls: 0.5562  loss_rpn_loc: 0.1105  time: 0.2976  data_time: 0.0021  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:51 d2.utils.events]:  eta: 16:33:36  iter: 479  total_loss: 0.6648  loss_cls: 0.001598  loss_box_reg: 0  loss_rpn_cls: 0.5605  loss_rpn_loc: 0.1022  time: 0.2977  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:44:57 d2.utils.events]:  eta: 16:33:35  iter: 499  total_loss: 0.6486  loss_cls: 0.001425  loss_box_reg: 0  loss_rpn_cls: 0.55  loss_rpn_loc: 0.0975  time: 0.2978  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:03 d2.utils.events]:  eta: 16:33:29  iter: 519  total_loss: 0.6421  loss_cls: 0.001662  loss_box_reg: 0  loss_rpn_cls: 0.5477  loss_rpn_loc: 0.09328  time: 0.2978  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:09 d2.utils.events]:  eta: 16:32:53  iter: 539  total_loss: 0.6611  loss_cls: 0.001311  loss_box_reg: 0  loss_rpn_cls: 0.5532  loss_rpn_loc: 0.105  time: 0.2978  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:15 d2.utils.events]:  eta: 16:33:13  iter: 559  total_loss: 0.6632  loss_cls: 0.001657  loss_box_reg: 0  loss_rpn_cls: 0.557  loss_rpn_loc: 0.1007  time: 0.2979  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:21 d2.utils.events]:  eta: 16:33:11  iter: 579  total_loss: 0.6622  loss_cls: 0.001142  loss_box_reg: 0  loss_rpn_cls: 0.5578  loss_rpn_loc: 0.1044  time: 0.2980  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:27 d2.utils.events]:  eta: 16:33:05  iter: 599  total_loss: 0.6213  loss_cls: 0.001068  loss_box_reg: 0  loss_rpn_cls: 0.5298  loss_rpn_loc: 0.09311  time: 0.2980  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:33 d2.utils.events]:  eta: 16:32:59  iter: 619  total_loss: 0.6763  loss_cls: 0.0009943  loss_box_reg: 0  loss_rpn_cls: 0.5623  loss_rpn_loc: 0.1093  time: 0.2981  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:39 d2.utils.events]:  eta: 16:32:53  iter: 639  total_loss: 0.6366  loss_cls: 0.0009293  loss_box_reg: 0  loss_rpn_cls: 0.5422  loss_rpn_loc: 0.09325  time: 0.2981  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:45 d2.utils.events]:  eta: 16:32:34  iter: 659  total_loss: 0.6238  loss_cls: 0.00126  loss_box_reg: 0  loss_rpn_cls: 0.5282  loss_rpn_loc: 0.09837  time: 0.2981  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:51 d2.utils.events]:  eta: 16:32:37  iter: 679  total_loss: 0.6192  loss_cls: 0.0009721  loss_box_reg: 0  loss_rpn_cls: 0.5221  loss_rpn_loc: 0.09713  time: 0.2981  data_time: 0.0018  lr: 1e-05  max_mem: 2825M
# [09/21 19:45:57 d2.utils.events]:  eta: 16:32:35  iter: 699  total_loss: 0.6161  loss_cls: 0.000666  loss_box_reg: 0  loss_rpn_cls: 0.5174  loss_rpn_loc: 0.09928  time: 0.2981  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:03 d2.utils.events]:  eta: 16:32:37  iter: 719  total_loss: 0.6165  loss_cls: 0.000991  loss_box_reg: 0  loss_rpn_cls: 0.5182  loss_rpn_loc: 0.09411  time: 0.2981  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:09 d2.utils.events]:  eta: 16:32:23  iter: 739  total_loss: 0.6011  loss_cls: 0.0007265  loss_box_reg: 0  loss_rpn_cls: 0.5081  loss_rpn_loc: 0.09445  time: 0.2982  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:15 d2.utils.events]:  eta: 16:32:17  iter: 759  total_loss: 0.5741  loss_cls: 0.0005534  loss_box_reg: 0  loss_rpn_cls: 0.4896  loss_rpn_loc: 0.08494  time: 0.2982  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:21 d2.utils.events]:  eta: 16:32:21  iter: 779  total_loss: 0.5806  loss_cls: 0.0005538  loss_box_reg: 0  loss_rpn_cls: 0.4922  loss_rpn_loc: 0.08787  time: 0.2982  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:27 d2.utils.events]:  eta: 16:32:11  iter: 799  total_loss: 0.5905  loss_cls: 0.000478  loss_box_reg: 0  loss_rpn_cls: 0.5007  loss_rpn_loc: 0.09267  time: 0.2982  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:33 d2.utils.events]:  eta: 16:32:09  iter: 819  total_loss: 0.5806  loss_cls: 0.0003908  loss_box_reg: 0  loss_rpn_cls: 0.4849  loss_rpn_loc: 0.09278  time: 0.2983  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:39 d2.utils.events]:  eta: 16:32:09  iter: 839  total_loss: 0.5785  loss_cls: 0.0003192  loss_box_reg: 0  loss_rpn_cls: 0.4905  loss_rpn_loc: 0.09169  time: 0.2983  data_time: 0.0021  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:45 d2.utils.events]:  eta: 16:32:04  iter: 859  total_loss: 0.551  loss_cls: 0.0003445  loss_box_reg: 0  loss_rpn_cls: 0.4706  loss_rpn_loc: 0.08235  time: 0.2983  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:51 d2.utils.events]:  eta: 16:31:49  iter: 879  total_loss: 0.5703  loss_cls: 0.0003483  loss_box_reg: 0  loss_rpn_cls: 0.4806  loss_rpn_loc: 0.09348  time: 0.2983  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:46:57 d2.utils.events]:  eta: 16:31:41  iter: 899  total_loss: 0.5721  loss_cls: 0.000261  loss_box_reg: 0  loss_rpn_cls: 0.4789  loss_rpn_loc: 0.09597  time: 0.2984  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:47:03 d2.utils.events]:  eta: 16:31:35  iter: 919  total_loss: 0.5419  loss_cls: 0.0001971  loss_box_reg: 0  loss_rpn_cls: 0.4533  loss_rpn_loc: 0.08389  time: 0.2984  data_time: 0.0021  lr: 1e-05  max_mem: 2825M
# [09/21 19:47:09 d2.utils.events]:  eta: 16:31:29  iter: 939  total_loss: 0.6103  loss_cls: 0.0001973  loss_box_reg: 0  loss_rpn_cls: 0.498  loss_rpn_loc: 0.1069  time: 0.2984  data_time: 0.0020  lr: 1e-05  max_mem: 2825M
# [09/21 19:47:15 d2.utils.events]:  eta: 16:31:18  iter: 959  total_loss: 0.5053  loss_cls: 0.0001617  loss_box_reg: 0  loss_rpn_cls: 0.4166  loss_rpn_loc: 0.0836  time: 0.2984  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:47:21 d2.utils.events]:  eta: 16:31:08  iter: 979  total_loss: 0.5398  loss_cls: 0.0001651  loss_box_reg: 0  loss_rpn_cls: 0.4465  loss_rpn_loc: 0.0973  time: 0.2984  data_time: 0.0019  lr: 1e-05  max_mem: 2825M
# [09/21 19:47:27 d2.utils.events]:  eta: 16:31:17  iter: 999  total_loss: 0.5206  loss_cls: 0.0001306  loss_box_reg: 0  loss_rpn_cls: 0.4344  loss_rpn_loc: 0.08833  time: 0.2985  data_time: 0.0022  lr: 1e-05  max_mem: 2825M

# %%
train()
# Out:
# [09/21 19:39:58 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# [09/21 19:39:58 d2.checkpoint.c2_model_loading]: Renaming Caffe2 weights ......
# [09/21 19:39:59 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up:
# | Names in Model    | Names in Checkpoint                         | Shapes                                          |
# |:------------------|:--------------------------------------------|:------------------------------------------------|
# | res2.0.conv1.*    | res2_0_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | res2.0.conv2.*    | res2_0_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,8,3,3)         |
# | res2.0.conv3.*    | res2_0_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res2.0.shortcut.* | res2_0_branch1_{bn_b,bn_rm,bn_riv,bn_s,w}   | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | res2.1.conv1.*    | res2_1_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res2.1.conv2.*    | res2_1_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,8,3,3)         |
# | res2.1.conv3.*    | res2_1_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res2.2.conv1.*    | res2_2_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res2.2.conv2.*    | res2_2_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,8,3,3)         |
# | res2.2.conv3.*    | res2_2_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (256,) (256,) (256,) (256,) (256,256,1,1)       |
# | res3.0.conv1.*    | res3_0_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,256,1,1)       |
# | res3.0.conv2.*    | res3_0_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,16,3,3)        |
# | res3.0.conv3.*    | res3_0_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.0.shortcut.* | res3_0_branch1_{bn_b,bn_rm,bn_riv,bn_s,w}   | (512,) (512,) (512,) (512,) (512,256,1,1)       |
# | res3.1.conv1.*    | res3_1_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.1.conv2.*    | res3_1_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,16,3,3)        |
# | res3.1.conv3.*    | res3_1_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.2.conv1.*    | res3_2_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.2.conv2.*    | res3_2_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,16,3,3)        |
# | res3.2.conv3.*    | res3_2_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.3.conv1.*    | res3_3_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res3.3.conv2.*    | res3_3_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,16,3,3)        |
# | res3.3.conv3.*    | res3_3_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (512,) (512,) (512,) (512,) (512,512,1,1)       |
# | res4.0.conv1.*    | res4_0_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,512,1,1)  |
# | res4.0.conv2.*    | res4_0_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.0.conv3.*    | res4_0_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.0.shortcut.* | res4_0_branch1_{bn_b,bn_rm,bn_riv,bn_s,w}   | (1024,) (1024,) (1024,) (1024,) (1024,512,1,1)  |
# | res4.1.conv1.*    | res4_1_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.1.conv2.*    | res4_1_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.1.conv3.*    | res4_1_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.10.conv1.*   | res4_10_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.10.conv2.*   | res4_10_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.10.conv3.*   | res4_10_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.11.conv1.*   | res4_11_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.11.conv2.*   | res4_11_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.11.conv3.*   | res4_11_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.12.conv1.*   | res4_12_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.12.conv2.*   | res4_12_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.12.conv3.*   | res4_12_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.13.conv1.*   | res4_13_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.13.conv2.*   | res4_13_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.13.conv3.*   | res4_13_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.14.conv1.*   | res4_14_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.14.conv2.*   | res4_14_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.14.conv3.*   | res4_14_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.15.conv1.*   | res4_15_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.15.conv2.*   | res4_15_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.15.conv3.*   | res4_15_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.16.conv1.*   | res4_16_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.16.conv2.*   | res4_16_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.16.conv3.*   | res4_16_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.17.conv1.*   | res4_17_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.17.conv2.*   | res4_17_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.17.conv3.*   | res4_17_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.18.conv1.*   | res4_18_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.18.conv2.*   | res4_18_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.18.conv3.*   | res4_18_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.19.conv1.*   | res4_19_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.19.conv2.*   | res4_19_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.19.conv3.*   | res4_19_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.2.conv1.*    | res4_2_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.2.conv2.*    | res4_2_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.2.conv3.*    | res4_2_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.20.conv1.*   | res4_20_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.20.conv2.*   | res4_20_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.20.conv3.*   | res4_20_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.21.conv1.*   | res4_21_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.21.conv2.*   | res4_21_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.21.conv3.*   | res4_21_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.22.conv1.*   | res4_22_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.22.conv2.*   | res4_22_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.22.conv3.*   | res4_22_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w} | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.3.conv1.*    | res4_3_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.3.conv2.*    | res4_3_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.3.conv3.*    | res4_3_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.4.conv1.*    | res4_4_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.4.conv2.*    | res4_4_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.4.conv3.*    | res4_4_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.5.conv1.*    | res4_5_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.5.conv2.*    | res4_5_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.5.conv3.*    | res4_5_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.6.conv1.*    | res4_6_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.6.conv2.*    | res4_6_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.6.conv3.*    | res4_6_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.7.conv1.*    | res4_7_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.7.conv2.*    | res4_7_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.7.conv3.*    | res4_7_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.8.conv1.*    | res4_8_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.8.conv2.*    | res4_8_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.8.conv3.*    | res4_8_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.9.conv1.*    | res4_9_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res4.9.conv2.*    | res4_9_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,32,3,3)   |
# | res4.9.conv3.*    | res4_9_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (1024,) (1024,) (1024,) (1024,) (1024,1024,1,1) |
# | res5.0.conv1.*    | res5_0_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,1024,1,1) |
# | res5.0.conv2.*    | res5_0_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,64,3,3)   |
# | res5.0.conv3.*    | res5_0_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | res5.0.shortcut.* | res5_0_branch1_{bn_b,bn_rm,bn_riv,bn_s,w}   | (2048,) (2048,) (2048,) (2048,) (2048,1024,1,1) |
# | res5.1.conv1.*    | res5_1_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | res5.1.conv2.*    | res5_1_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,64,3,3)   |
# | res5.1.conv3.*    | res5_1_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | res5.2.conv1.*    | res5_2_branch2a_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | res5.2.conv2.*    | res5_2_branch2b_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,64,3,3)   |
# | res5.2.conv3.*    | res5_2_branch2c_{bn_b,bn_rm,bn_riv,bn_s,w}  | (2048,) (2048,) (2048,) (2048,) (2048,2048,1,1) |
# | stem.conv1.norm.* | res_conv1_bn_{b,rm,riv,s}                   | (64,) (64,) (64,) (64,)                         |
# | stem.conv1.weight | conv1_w                                     | (64, 3, 7, 7)                                   |
# Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# The checkpoint state_dict contains keys that are not used by the model:
#   linear.{bias, weight}
# [09/21 19:39:59 d2.engine.train_loop]: Starting training from iteration 0
# /home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /opt/conda/conda-bld/pytorch_1631630815121/work/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# [09/21 19:40:05 d2.utils.events]:  eta: 16:18:50  iter: 19  total_loss: 1.734  loss_cls: 0.5857  loss_box_reg: 0  loss_rpn_cls: 0.6819  loss_rpn_loc: 0.4717  time: 0.2925  data_time: 0.0129  lr: 1.9081e-06  max_mem: 1595M
# [09/21 19:40:11 d2.utils.events]:  eta: 16:22:18  iter: 39  total_loss: 1.543  loss_cls: 0.4114  loss_box_reg: 0  loss_rpn_cls: 0.6803  loss_rpn_loc: 0.441  time: 0.2947  data_time: 0.0022  lr: 3.9061e-06  max_mem: 1595M
# [09/21 19:40:17 d2.utils.events]:  eta: 16:34:49  iter: 59  total_loss: 1.311  loss_cls: 0.2067  loss_box_reg: 0  loss_rpn_cls: 0.6782  loss_rpn_loc: 0.4511  time: 0.2968  data_time: 0.0020  lr: 5.9041e-06  max_mem: 1595M
# [09/21 19:40:23 d2.utils.events]:  eta: 16:28:58  iter: 79  total_loss: 1.177  loss_cls: 0.1015  loss_box_reg: 0  loss_rpn_cls: 0.6742  loss_rpn_loc: 0.4077  time: 0.2958  data_time: 0.0023  lr: 7.9021e-06  max_mem: 1595M
# [09/21 19:40:29 d2.utils.events]:  eta: 16:32:39  iter: 99  total_loss: 1.109  loss_cls: 0.05713  loss_box_reg: 0  loss_rpn_cls: 0.6685  loss_rpn_loc: 0.3751  time: 0.2964  data_time: 0.0021  lr: 9.9001e-06  max_mem: 1595M
# [09/21 19:40:35 d2.utils.events]:  eta: 16:34:22  iter: 119  total_loss: 1.075  loss_cls: 0.03548  loss_box_reg: 0  loss_rpn_cls: 0.6646  loss_rpn_loc: 0.3761  time: 0.2967  data_time: 0.0021  lr: 1e-05  max_mem: 1595M
# [09/21 19:40:41 d2.utils.events]:  eta: 16:35:37  iter: 139  total_loss: 1.087  loss_cls: 0.02563  loss_box_reg: 0  loss_rpn_cls: 0.6586  loss_rpn_loc: 0.4042  time: 0.2973  data_time: 0.0019  lr: 1e-05  max_mem: 1595M
# [09/21 19:40:47 d2.utils.events]:  eta: 16:34:57  iter: 159  total_loss: 1.014  loss_cls: 0.01978  loss_box_reg: 0  loss_rpn_cls: 0.6503  loss_rpn_loc: 0.3446  time: 0.2967  data_time: 0.0019  lr: 1e-05  max_mem: 1595M
# [09/21 19:40:53 d2.utils.events]:  eta: 16:34:51  iter: 179  total_loss: 1.037  loss_cls: 0.01548  loss_box_reg: 0  loss_rpn_cls: 0.6491  loss_rpn_loc: 0.3719  time: 0.2966  data_time: 0.0020  lr: 1e-05  max_mem: 1595M
# [09/21 19:40:59 d2.utils.events]:  eta: 16:31:07  iter: 199  total_loss: 0.9955  loss_cls: 0.01249  loss_box_reg: 0  loss_rpn_cls: 0.6396  loss_rpn_loc: 0.3442  time: 0.2951  data_time: 0.0030  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:04 d2.utils.events]:  eta: 16:28:32  iter: 219  total_loss: 1.039  loss_cls: 0.009785  loss_box_reg: 0  loss_rpn_cls: 0.6437  loss_rpn_loc: 0.3863  time: 0.2949  data_time: 0.0023  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:10 d2.utils.events]:  eta: 16:30:18  iter: 239  total_loss: 0.8888  loss_cls: 0.007763  loss_box_reg: 0  loss_rpn_cls: 0.6179  loss_rpn_loc: 0.2642  time: 0.2953  data_time: 0.0023  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:16 d2.utils.events]:  eta: 16:30:58  iter: 259  total_loss: 0.9464  loss_cls: 0.006366  loss_box_reg: 0  loss_rpn_cls: 0.6275  loss_rpn_loc: 0.312  time: 0.2956  data_time: 0.0019  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:22 d2.utils.events]:  eta: 16:31:45  iter: 279  total_loss: 0.9055  loss_cls: 0.004921  loss_box_reg: 0  loss_rpn_cls: 0.6188  loss_rpn_loc: 0.2817  time: 0.2954  data_time: 0.0020  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:28 d2.utils.events]:  eta: 16:29:18  iter: 299  total_loss: 0.8693  loss_cls: 0.003954  loss_box_reg: 0  loss_rpn_cls: 0.6138  loss_rpn_loc: 0.2516  time: 0.2949  data_time: 0.0022  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:34 d2.utils.events]:  eta: 16:26:25  iter: 319  total_loss: 0.7899  loss_cls: 0.003184  loss_box_reg: 0  loss_rpn_cls: 0.5941  loss_rpn_loc: 0.1915  time: 0.2939  data_time: 0.0020  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:40 d2.utils.events]:  eta: 16:25:03  iter: 339  total_loss: 0.8176  loss_cls: 0.002748  loss_box_reg: 0  loss_rpn_cls: 0.6078  loss_rpn_loc: 0.2093  time: 0.2940  data_time: 0.0020  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:46 d2.utils.events]:  eta: 16:23:25  iter: 359  total_loss: 0.704  loss_cls: 0.002279  loss_box_reg: 0  loss_rpn_cls: 0.5742  loss_rpn_loc: 0.1274  time: 0.2939  data_time: 0.0019  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:51 d2.utils.events]:  eta: 16:23:00  iter: 379  total_loss: 0.6961  loss_cls: 0.001729  loss_box_reg: 0  loss_rpn_cls: 0.5712  loss_rpn_loc: 0.1264  time: 0.2938  data_time: 0.0022  lr: 1e-05  max_mem: 1595M
# [09/21 19:41:57 d2.utils.events]:  eta: 16:24:21  iter: 399  total_loss: 0.6827  loss_cls: 0.001456  loss_box_reg: 0  loss_rpn_cls: 0.5642  loss_rpn_loc: 0.1101  time: 0.2941  data_time: 0.0019  lr: 1e-05  max_mem: 1595M
# [09/21 19:42:03 d2.utils.events]:  eta: 16:25:22  iter: 419  total_loss: 0.6543  loss_cls: 0.001534  loss_box_reg: 0  loss_rpn_cls: 0.5592  loss_rpn_loc: 0.09842  time: 0.2943  data_time: 0.0020  lr: 1e-05  max_mem: 1595M
# [09/21 19:42:09 d2.utils.events]:  eta: 16:26:19  iter: 439  total_loss: 0.6845  loss_cls: 0.001432  loss_box_reg: 0  loss_rpn_cls: 0.573  loss_rpn_loc: 0.1037  time: 0.2943  data_time: 0.0020  lr: 1e-05  max_mem: 1595M
# Process ProducerForkProcess-11:
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process CommanderForkProcess-10:
#   File "/home/user/.local/lib/python3.8/site-packages/concurrentbuffer/producer.py", line 59, in run
#     for message in iter(self._message_queue.get, STOP_MESSAGE):
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/multiprocessing/queues.py", line 97, in get
#     res = self._recv_bytes()
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/user/.local/lib/python3.8/site-packages/concurrentbuffer/commander.py", line 55, in run
#     buffer_id = self._buffer_state_memory.get_free_buffer_id()
# KeyboardInterrupt
#   File "/home/user/.local/lib/python3.8/site-packages/concurrentbuffer/state.py", line 87, in get_free_buffer_id
#     return self._get_buffer_id_with_state(
#   File "/home/user/.local/lib/python3.8/site-packages/concurrentbuffer/state.py", line 22, in wrapper
#     out = method(self, *args, **kwargs)
#   File "/home/user/.local/lib/python3.8/site-packages/concurrentbuffer/state.py", line 66, in _get_buffer_id_with_state
#     buffer_ids = self._get_buffer_ids_with_state(state=state)
#   File "/home/user/.local/lib/python3.8/site-packages/concurrentbuffer/state.py", line 62, in _get_buffer_ids_with_state
#     return list(np.where(state_buffer == state.value)[0])
# KeyboardInterrupt
# [09/21 19:42:12 d2.engine.hooks]: Overall training speed: 445 iterations in 0:02:11 (0.2950 s / it)
# [09/21 19:42:12 d2.engine.hooks]: Total training time: 0:02:11 (0:00:00 on hooks)
# [09/21 19:42:12 d2.utils.events]:  eta: 16:26:09  iter: 447  total_loss: 0.6645  loss_cls: 0.001431  loss_box_reg: 0  loss_rpn_cls: 0.5586  loss_rpn_loc: 0.102  time: 0.2944  data_time: 0.0021  lr: 1e-05  max_mem: 1595M
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-2da0ffaf5447>", line 1, in <module>
#     train()
#   File "<ipython-input-7-71237222ffa3>", line 27, in train
#     trainer.train()
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/detectron2/engine/defaults.py", line 487, in train
#     super().train(self.start_iter, self.max_iter)
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/detectron2/engine/train_loop.py", line 149, in train
#     self.run_step()
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/detectron2/engine/defaults.py", line 497, in run_step
#     self._trainer.run_step()
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/detectron2/engine/train_loop.py", line 285, in run_step
#     losses.backward()
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/torch/_tensor.py", line 255, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/torch/autograd/__init__.py", line 147, in backward
#     Variable._execution_engine.run_backward(
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/user/miniconda3/envs/detectron2/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-8-2da0ffaf5447> in <module>
# ----> 1 train()
#
# <ipython-input-7-71237222ffa3> in train()
#      26     trainer.resume_or_load(resume=False)
# ---> 27     trainer.train()
#      28
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/detectron2/engine/defaults.py in train(self)
#     486         """
# --> 487         super().train(self.start_iter, self.max_iter)
#     488         if len(self.cfg.TEST.EXPECTED_RESULTS) and comm.is_main_process():
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/detectron2/engine/train_loop.py in train(self, start_iter, max_iter)
#     148                     self.before_step()
# --> 149                     self.run_step()
#     150                     self.after_step()
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/detectron2/engine/defaults.py in run_step(self)
#     496         self._trainer.iter = self.iter
# --> 497         self._trainer.run_step()
#     498
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/detectron2/engine/train_loop.py in run_step(self)
#     284         self.optimizer.zero_grad()
# --> 285         losses.backward()
#     286
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     146
# --> 147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         stb = value._render_traceback_()
#    2045                     except Exception:
# -> 2046                         stb = self.InteractiveTB.structured_traceback(etype,
#    2047                                             value, tb, tb_offset=tb_offset)
#    2048
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1433         else:
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1333         if mode in self.verbose_modes:
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1190         """Return a nice text document describing the traceback."""
#    1191
# -> 1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                                tb_offset)
#    1194
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/miniconda3/envs/detectron2/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
